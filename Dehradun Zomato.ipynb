# %%
import pandas as pd

# %%
df=pd.read_csv('Dehradun_Zomatao_Dataset.csv',index_col=0) #index_col =0 tells pandas that the first column is index of csv
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df.drop('longitude',axis=1,inplace=True)

# %%
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df.drop('city',axis=1,inplace=True)
df.drop('country_id',axis=1,inplace=True)
df.drop('city_id',axis=1,inplace=True)
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df.drop('locality_verbose',axis=1,inplace=True)
df.drop('photo_count',axis=1,inplace=True)
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df.drop('opentable_support',axis=1,inplace=True)
df.drop('delivery',axis=1,inplace=True)
df.drop('takeaway',axis=1,inplace=True)
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df=df.rename(columns={
    'average_cost_for_two':'cost',
})
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
df.drop('establishment',axis=1,inplace=True)
df.drop('url',axis=1,inplace=True)
df.drop('address',axis=1,inplace=True)
df
# Out:
#         res_id                                name  \
# 0      3500024                         Doon Darbar
# 1      3500424                      Gaylord Xpress
# 2      3500218                        Uss Da Dhaba
# 3     18754629                       Dominos Pizza
# 4      3502144                     Mannu Fast Food
# ...        ...                                 ...
# 2572   3500497                           Mirabilia
# 2573   3500393               The Buffet Snack Shop
# 2574  18888295                     The Swings Cafe
# 2575   3500913                         Edens Grove
# 2576   3500096  Vatika Restaurant - Hotel Madhuban
#
#                                   locality   latitude  \
# 0                            Paltan Bazaar  30.320153
# 1                            Paltan Bazaar  30.324001
# 2                              Race Course  30.315865
# 3                                   Rajpur  30.333850
# 4                                   Raipur  30.319999
# ...

# %%
df['type'].value_counts()
# Out:
# Quick Bites        750
# Casual Dining      673
# Café               450
# Bakery             144
# Dhaba              133
# Fine Dining         94
# Dessert Parlour     81
# Sweet Shop          68
# Bar                 31
# Food Court          25
# Restaurant/Shop     23
# Beverage Shop       23
# Lounge              20
# Food Truck          20
# Microbrewery        13
# Kiosk               13
# Confectionery        7
# Pub                  3
# Butcher Shop         2
# Mess                 2
# Bhojanalya           1
# Paan Shop            1
# Name: type, dtype: int64

# %%
df['type'].replace('Café','Cafe',regex=True)
df
# Out:
#         res_id                                name  \
# 0      3500024                         Doon Darbar
# 1      3500424                      Gaylord Xpress
# 2      3500218                        Uss Da Dhaba
# 3     18754629                       Dominos Pizza
# 4      3502144                     Mannu Fast Food
# ...        ...                                 ...
# 2572   3500497                           Mirabilia
# 2573   3500393               The Buffet Snack Shop
# 2574  18888295                     The Swings Cafe
# 2575   3500913                         Edens Grove
# 2576   3500096  Vatika Restaurant - Hotel Madhuban
#
#                                   locality   latitude  \
# 0                            Paltan Bazaar  30.320153
# 1                            Paltan Bazaar  30.324001
# 2                              Race Course  30.315865
# 3                                   Rajpur  30.333850
# 4                                   Raipur  30.319999
# ...

# %%
df['type'].value_counts()

# data=df[df['type']=="Café"]['type']
# data
# print(type('Café'))

df['type'].str.replace('é','e',regex=True)
df['type'].value_counts()
# Out:
# Quick Bites        750
# Casual Dining      673
# Café               450
# Bakery             144
# Dhaba              133
# Fine Dining         94
# Dessert Parlour     81
# Sweet Shop          68
# Bar                 31
# Food Court          25
# Restaurant/Shop     23
# Beverage Shop       23
# Lounge              20
# Food Truck          20
# Microbrewery        13
# Kiosk               13
# Confectionery        7
# Pub                  3
# Butcher Shop         2
# Mess                 2
# Bhojanalya           1
# Paan Shop            1
# Name: type, dtype: int64

# %%
df.drop('res_id',axis=1,inplace=True)
df
# Out:
#                                     name  \
# 0                            Doon Darbar
# 1                         Gaylord Xpress
# 2                           Uss Da Dhaba
# 3                          Dominos Pizza
# 4                        Mannu Fast Food
# ...                                  ...
# 2572                           Mirabilia
# 2573               The Buffet Snack Shop
# 2574                     The Swings Cafe
# 2575                         Edens Grove
# 2576  Vatika Restaurant - Hotel Madhuban
#
#                                   locality   latitude  \
# 0                            Paltan Bazaar  30.320153
# 1                            Paltan Bazaar  30.324001
# 2                              Race Course  30.315865
# 3                                   Rajpur  30.333850
# 4                                   Raipur  30.319999
# ...                                    ...        ...
# 2572                              Karanpur  30.315838
# ...

# %%
df.drop('latitude',axis=1,inplace=True)
df
# Out:
#                                     name  \
# 0                            Doon Darbar
# 1                         Gaylord Xpress
# 2                           Uss Da Dhaba
# 3                          Dominos Pizza
# 4                        Mannu Fast Food
# ...                                  ...
# 2572                           Mirabilia
# 2573               The Buffet Snack Shop
# 2574                     The Swings Cafe
# 2575                         Edens Grove
# 2576  Vatika Restaurant - Hotel Madhuban
#
#                                   locality  \
# 0                            Paltan Bazaar
# 1                            Paltan Bazaar
# 2                              Race Course
# 3                                   Rajpur
# 4                                   Raipur
# ...                                    ...
# 2572                              Karanpur
# 2573                            Chukkuwala
# 2574                                Jakhan
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                     name       locality  \
# 0                            Doon Darbar  Paltan Bazaar
# 1                         Gaylord Xpress  Paltan Bazaar
# 2                           Uss Da Dhaba    Race Course
# 3                          Dominos Pizza         Rajpur
# 4                        Mannu Fast Food         Raipur
# ...                                  ...            ...
# 2396                                  KJ    Garhi Cantt
# 2398                       Mr Burger Hut  Subhash Nagar
# 2404                    K.K Kabab Corner         Jakhan
# 2405                    Gagar Restaurant       Morowala
# 2406  Burger Singh - Big Punjabi Burgers       Ballupur
#
#                               cuisines  \
# 0                North Indian, Mughlai
# 1                            Fast Food
# 2                         North Indian
# 3                     Pizza, Fast Food
# 4     Fast Food, North Indian, Chinese
# ...                                ...
# ...

# %%
df.to_csv(r'C:\Users\GSP-LAP-009\OneDrive\Desktop\Data Analytics Projects\Complete Data Analytics Projects\Explaratory_Project-2\zomato.csv',index=False,header=True)
